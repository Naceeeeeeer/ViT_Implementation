# %%
import numpy as np

from tqdm import tqdm, trange

import torch
import torch.nn as nn
from torch.optim import Adam
from torch.nn import CrossEntropyLoss
from torch.utils.data import DataLoader

from torchvision.transforms import ToTensor
from torchvision.datasets.mnist import MNIST

np.random.seed(0)
torch.manual_seed(0)

# %%
def main():
    transform = ToTensor()

    train_set = MNIST(root='./../datasets', train=True, download=True, transform=transform)
    test_set = MNIST(root='./../datasets', train=False, download=True, transform=transform)

    train_loader = DataLoader(train_set, shuffle=True, batch_size=128)
    test_loader = DataLoader(test_set, shuffle=False, batch_size=128)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print("Using device: ", device, f"({torch.cuda.get_device_name(device)})" if torch.cuda.is_available() else "")
    model = MyViT((1, 28, 28), n_patches=7, n_blocks=2, hidden_d=8, n_heads=2, out_d=10).to(device)
    N_EPOCHS = 5
    LR = 0.005

    optimizer = Adam(model.parameters(), lr=LR)
    criterion = CrossEntropyLoss()
    for epoch in trange(N_EPOCHS, desc="Training"):
        train_loss = 0.0
        for batch in tqdm(train_loader, desc=f"Epoch {epoch + 1} in training", leave=False):
            x, y = batch
            x, y = x.to(device), y.to(device)
            y_hat = model(x)
            loss = criterion(y_hat, y)

            train_loss += loss.detach().cpu().item() / len(train_loader)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        print(f"Epoch {epoch + 1}/{N_EPOCHS} loss: {train_loss:.2f}")

    with torch.no_grad():
        correct, total = 0, 0
        test_loss = 0.0
        for batch in tqdm(test_loader, desc="Testing"):
            x, y = batch
            x, y = x.to(device), y.to(device)
            y_hat = model(x)
            loss = criterion(y_hat, y)
            test_loss += loss.detach().cpu().item() / len(test_loader)

            correct += torch.sum(torch.argmax(y_hat, dim=1) == y).detach().cpu().item()
            total += len(x)
        print(f"Test loss: {test_loss:.2f}")
        print(f"Test accuracy: {correct / total * 100:.2f}%")

# %%
class MyViT(nn.Module):
  def __init__(self):
    super(MyViT, self).__init__()

  def forward(self, images):
    pass

# %%
def patchify(images, n_patches):
    n, c, h, w = images.shape

    assert h == w, "Patchify method is implemented for square images only"

    patches = torch.zeros(n, n_patches ** 2, h * w * c // n_patches ** 2)
    patch_size = h // n_patches

    for idx, image in enumerate(images):
        for i in range(n_patches):
            for j in range(n_patches):
                patch = image[:, i * patch_size: (i + 1) * patch_size, j * patch_size: (j + 1) * patch_size]
                patches[idx, i * n_patches + j] = patch.flatten()
    return patches

# %%
class MyViT(nn.Module):
  def __init__(self, chw=(1, 28, 28), n_patches=7):
    super(MyViT, self).__init__()

    self.chw = chw 
    self.n_patches = n_patches

    assert chw[1] % n_patches == 0, "Input shape not entirely divisible by number of patches"
    assert chw[2] % n_patches == 0, "Input shape not entirely divisible by number of patches"

  def forward(self, images):
    patches = patchify(images, self.n_patches)
    return patches

# %%
if __name__ == '__main__':
  model = MyViT(
    chw=(1, 28, 28),
    n_patches=7
  )

  x = torch.randn(7, 1, 28, 28)
  print(model(x).shape)
# Out:
# torch.Size([7, 49, 16])

# %%
class MyViT(nn.Module):
  def __init__(self, chw=(1, 28, 28), n_patches=7):
    super(MyViT, self).__init__()

    self.chw = chw
    self.n_patches = n_patches

    assert chw[1] % n_patches == 0, "Input shape not entirely divisible by number of patches"
    assert chw[2] % n_patches == 0, "Input shape not entirely divisible by number of patches"
    self.patch_size = (chw[1] / n_patches, chw[2] / n_patches)
    self.input_d = int(chw[0] * self.patch_size[0] * self.patch_size[1])
    self.linear_mapper = nn.Linear(self.input_d, self.hidden_d)

  def forward(self, images):
    patches = patchify(images, self.n_patches)
    tokens = self.linear_mapper(patches)
    return tokens

# %%
class MyViT(nn.Module):
  def __init__(self, chw=(1, 28, 28), n_patches=7):
    super(MyViT, self).__init__()
    self.chw = chw
    self.n_patches = n_patches

    assert chw[1] % n_patches == 0, "Input shape not entirely divisible by number of patches"
    assert chw[2] % n_patches == 0, "Input shape not entirely divisible by number of patches"
    self.patch_size = (chw[1] / n_patches, chw[2] / n_patches)
    self.input_d = int(chw[0] * self.patch_size[0] * self.patch_size[1])
    self.linear_mapper = nn.Linear(self.input_d, self.hidden_d)
    self.class_token = nn.Parameter(torch.rand(1, self.hidden_d))

  def forward(self, images):
    patches = patchify(images, self.n_patches)
    tokens = self.linear_mapper(patches)
    tokens = torch.stack([torch.vstack((self.class_token, tokens[i])) for i in range(len(tokens))])
    return tokens

# %%
def get_positional_embeddings(sequence_length, d):
    result = torch.ones(sequence_length, d)
    for i in range(sequence_length):
        for j in range(d):
            result[i][j] = np.sin(i / (10000 ** (j / d))) if j % 2 == 0 else np.cos(i / (10000 ** ((j - 1) / d)))
    return result

# %%
class MyViT(nn.Module):
  def __init__(self, chw=(1, 28, 28), n_patches=7):
    super(MyViT, self).__init__()
    self.chw = chw 
    self.n_patches = n_patches

    assert chw[1] % n_patches == 0, "Input shape not entirely divisible by number of patches"
    assert chw[2] % n_patches == 0, "Input shape not entirely divisible by number of patches"
    self.patch_size = (chw[1] / n_patches, chw[2] / n_patches)

    self.input_d = int(chw[0] * self.patch_size[0] * self.patch_size[1])
    self.linear_mapper = nn.Linear(self.input_d, self.hidden_d)
    self.class_token = nn.Parameter(torch.rand(1, self.hidden_d))
    self.pos_embed = nn.Parameter(torch.tensor(get_positional_embeddings(self.n_patches ** 2 + 1, self.hidden_d)))
    self.pos_embed.requires_grad = False

  def forward(self, images):
    patches = patchify(images, self.n_patches)
    tokens = self.linear_mapper(patches)

    tokens = torch.stack([torch.vstack((self.class_token, tokens[i])) for i in range(len(tokens))])
    pos_embed = self.pos_embed.repeat(n, 1, 1)
    out = tokens + pos_embed
    return out

# %%
class MyMSA(nn.Module):
    def __init__(self, d, n_heads=2):
        super(MyMSA, self).__init__()
        self.d = d
        self.n_heads = n_heads

        assert d % n_heads == 0, f"Can't divide dimension {d} into {n_heads} heads"

        d_head = int(d / n_heads)
        self.q_mappings = nn.ModuleList([nn.Linear(d_head, d_head) for _ in range(self.n_heads)])
        self.k_mappings = nn.ModuleList([nn.Linear(d_head, d_head) for _ in range(self.n_heads)])
        self.v_mappings = nn.ModuleList([nn.Linear(d_head, d_head) for _ in range(self.n_heads)])
        self.d_head = d_head
        self.softmax = nn.Softmax(dim=-1)

    def forward(self, sequences):

        result = []
        for sequence in sequences:
            seq_result = []
            for head in range(self.n_heads):
                q_mapping = self.q_mappings[head]
                k_mapping = self.k_mappings[head]
                v_mapping = self.v_mappings[head]

                seq = sequence[:, head * self.d_head: (head + 1) * self.d_head]
                q, k, v = q_mapping(seq), k_mapping(seq), v_mapping(seq)

                attention = self.softmax(q @ k.T / (self.d_head ** 0.5))
                seq_result.append(attention @ v)
            result.append(torch.hstack(seq_result))
        return torch.cat([torch.unsqueeze(r, dim=0) for r in result])

# %%
class MyViTBlock(nn.Module):
    def __init__(self, hidden_d, n_heads, mlp_ratio=4):
        super(MyViTBlock, self).__init__()
        self.hidden_d = hidden_d
        self.n_heads = n_heads

        self.norm1 = nn.LayerNorm(hidden_d)
        self.mhsa = MyMSA(hidden_d, n_heads)
        self.norm2 = nn.LayerNorm(hidden_d)
        self.mlp = nn.Sequential(
            nn.Linear(hidden_d, mlp_ratio * hidden_d),
            nn.GELU(),
            nn.Linear(mlp_ratio * hidden_d, hidden_d)
        )

    def forward(self, x):
        out = x + self.mhsa(self.norm1(x))
        out = out + self.mlp(self.norm2(out))
        return out

# %%
if __name__ == '__main__':
  model = MyViTBlock(hidden_d=8, n_heads=2)

  x = torch.randn(7, 50, 8)  
  print(model(x).shape)
# Out:
# torch.Size([7, 50, 8])

# %%
class MyViT(nn.Module):
    def __init__(self, chw, n_patches=7, n_blocks=2, hidden_d=8, n_heads=2, out_d=10):
        super(MyViT, self).__init__()
        
        self.chw = chw 
        self.n_patches = n_patches
        self.n_blocks = n_blocks
        self.n_heads = n_heads
        self.hidden_d = hidden_d
        assert chw[1] % n_patches == 0, "Input shape not entirely divisible by number of patches"
        assert chw[2] % n_patches == 0, "Input shape not entirely divisible by number of patches"
        self.patch_size = (chw[1] / n_patches, chw[2] / n_patches)

        self.input_d = int(chw[0] * self.patch_size[0] * self.patch_size[1])
        self.linear_mapper = nn.Linear(self.input_d, self.hidden_d)
        
        self.class_token = nn.Parameter(torch.rand(1, self.hidden_d))
        
        self.register_buffer('positional_embeddings', get_positional_embeddings(n_patches ** 2 + 1, hidden_d), persistent=False)
        
        self.blocks = nn.ModuleList([MyViTBlock(hidden_d, n_heads) for _ in range(n_blocks)])

    def forward(self, images):
        n, c, h, w = images.shape
        patches = patchify(images, self.n_patches).to(self.positional_embeddings.device)
        
        tokens = self.linear_mapper(patches)
        
        tokens = torch.cat((self.class_token.expand(n, 1, -1), tokens), dim=1)
        
        out = tokens + self.positional_embeddings.repeat(n, 1, 1)
        
        for block in self.blocks:
            out = block(out)
            
        return out

# %%
class MyViT(nn.Module):
    def __init__(self, chw, n_patches=7, n_blocks=2, hidden_d=8, n_heads=2, out_d=10):
        super(MyViT, self).__init__()
        
        self.chw = chw 
        self.n_patches = n_patches
        self.n_blocks = n_blocks
        self.n_heads = n_heads
        self.hidden_d = hidden_d
        
        assert chw[1] % n_patches == 0, "Input shape not entirely divisible by number of patches"
        assert chw[2] % n_patches == 0, "Input shape not entirely divisible by number of patches"
        self.patch_size = (chw[1] / n_patches, chw[2] / n_patches)

        self.input_d = int(chw[0] * self.patch_size[0] * self.patch_size[1])
        self.linear_mapper = nn.Linear(self.input_d, self.hidden_d)
        
        self.class_token = nn.Parameter(torch.rand(1, self.hidden_d))
        
        self.register_buffer('positional_embeddings', get_positional_embeddings(n_patches ** 2 + 1, hidden_d), persistent=False)
        
        self.blocks = nn.ModuleList([MyViTBlock(hidden_d, n_heads) for _ in range(n_blocks)])
        
        self.mlp = nn.Sequential(
            nn.Linear(self.hidden_d, out_d),
            nn.Softmax(dim=-1)
        )

    def forward(self, images):
        n, c, h, w = images.shape
        patches = patchify(images, self.n_patches).to(self.positional_embeddings.device)
        
        tokens = self.linear_mapper(patches)
        
        tokens = torch.cat((self.class_token.expand(n, 1, -1), tokens), dim=1)
        
        out = tokens + self.positional_embeddings.repeat(n, 1, 1)
        
        for block in self.blocks:
            out = block(out)
            
        out = out[:, 0]
        
        return self.mlp(out)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = MyViT((1, 28, 28), n_patches=7, n_blocks=2, hidden_d=8, n_heads=2, out_d=10).to(device)

# %%
import numpy as np
from tqdm import tqdm, trange
import torch
import torch.nn as nn
from torch.optim import Adam
from torch.nn import CrossEntropyLoss
from torch.utils.data import DataLoader
from torchvision.transforms import ToTensor
from torchvision.datasets.mnist import MNIST

np.random.seed(0)
torch.manual_seed(0)


def main():
    transform = ToTensor()

    train_set = MNIST(root='./../datasets', train=True, download=True, transform=transform)
    test_set = MNIST(root='./../datasets', train=False, download=True, transform=transform)

    train_loader = DataLoader(train_set, shuffle=True, batch_size=128)
    test_loader = DataLoader(test_set, shuffle=False, batch_size=128)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print("Using device: ", device, f"({torch.cuda.get_device_name(device)})" if torch.cuda.is_available() else "")
    model = MyViT((1, 28, 28), n_patches=7, n_blocks=2, hidden_d=8, n_heads=2, out_d=10).to(device)
    N_EPOCHS = 5
    LR = 0.005

    optimizer = Adam(model.parameters(), lr=LR)
    criterion = CrossEntropyLoss()
    for epoch in trange(N_EPOCHS, desc="Training"):
        train_loss = 0.0
        for batch in tqdm(train_loader, desc=f"Epoch {epoch + 1} in training", leave=False):
            x, y = batch
            x, y = x.to(device), y.to(device)
            y_hat = model(x)
            loss = criterion(y_hat, y)

            train_loss += loss.detach().cpu().item() / len(train_loader)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        print(f"Epoch {epoch + 1}/{N_EPOCHS} loss: {train_loss:.2f}")

    with torch.no_grad():
        actual_labels = []
        predicted_labels = []

        for batch in tqdm(test_loader, desc="Making Predictions"):
            x, y = batch
            x, y = x.to(device), y.to(device)
            y_hat = model(x)

            _, predicted = torch.max(y_hat, 1)
            actual_labels.extend(y.cpu().numpy())
            predicted_labels.extend(predicted.cpu().numpy())

        print("Actual labels for the first 10 samples:")
        print(actual_labels[:10])
        print("Predicted labels for the first 10 samples:")
        print(predicted_labels[:10])
    with torch.no_grad():
        correct, total = 0, 0
        test_loss = 0.0
        predicted_labels = []

        for batch in tqdm(test_loader, desc="Testing"):
            x, y = batch
            x, y = x.to(device), y.to(device)
            y_hat = model(x)
            loss = criterion(y_hat, y)
            test_loss += loss.detach().cpu().item() / len(test_loader)

            _, predicted = torch.max(y_hat, 1)
            predicted_labels.extend(predicted.cpu().numpy())

            correct += torch.sum(predicted == y).detach().cpu().item()
            total += len(x)

        print(f"Test loss: {test_loss:.2f}")
        print(f"Test accuracy: {correct / total * 100:.2f}%")

        print("Predicted labels for the first 10 samples:")
        print(predicted_labels[:10])


class MyViTBlock(nn.Module):
    def __init__(self, hidden_d, n_heads, mlp_ratio=4):
        super(MyViTBlock, self).__init__()
        self.hidden_d = hidden_d
        self.n_heads = n_heads

        self.norm1 = nn.LayerNorm(hidden_d)
        self.mhsa = MyMSA(hidden_d, n_heads)
        self.norm2 = nn.LayerNorm(hidden_d)
        self.mlp = nn.Sequential(
            nn.Linear(hidden_d, mlp_ratio * hidden_d),
            nn.GELU(),
            nn.Linear(mlp_ratio * hidden_d, hidden_d)
        )

    def forward(self, x):
        out = x + self.mhsa(self.norm1(x))
        out = out + self.mlp(self.norm2(out))
        return out


class MyViT(nn.Module):
    def __init__(self, chw, n_patches=7, n_blocks=2, hidden_d=8, n_heads=2, out_d=10):
        super(MyViT, self).__init__()

        self.chw = chw  
        self.n_patches = n_patches
        self.n_blocks = n_blocks
        self.n_heads = n_heads
        self.hidden_d = hidden_d

        assert chw[1] % n_patches == 0, "Input shape not entirely divisible by the number of patches"
        assert chw[2] % n_patches == 0, "Input shape not entirely divisible by the number of patches"
        self.patch_size = (chw[1] // n_patches, chw[2] // n_patches)

        self.input_d = int(chw[0] * self.patch_size[0] * self.patch_size[1])
        self.linear_mapper = nn.Linear(self.input_d, hidden_d)

        self.class_token = nn.Parameter(torch.rand(1, hidden_d))
        self.register_buffer('positional_embeddings', get_positional_embeddings(n_patches ** 2 + 1, hidden_d),
                             persistent=False)

        self.blocks = nn.ModuleList([MyViTBlock(hidden_d, n_heads) for _ in range(n_blocks)])
        self.mlp = nn.Sequential(
            nn.Linear(hidden_d, out_d),
        )

    def forward(self, images):
        n, c, h, w = images.shape
        patches = patchify(images, self.n_patches).to(self.positional_embeddings.device)

        tokens = self.linear_mapper(patches)
        tokens = torch.cat((self.class_token.expand(n, 1, -1), tokens), dim=1)
        out = tokens + self.positional_embeddings.repeat(n, 1, 1)

        for block in self.blocks:
            out = block(out)

        out = out[:, 0]
        out = self.mlp(out)

        return out


class MyViTBlock(nn.Module):
    def __init__(self, hidden_d, n_heads, mlp_ratio=4):
        super(MyViTBlock, self).__init__()
        self.hidden_d = hidden_d
        self.n_heads = n_heads

        self.norm1 = nn.LayerNorm(hidden_d)
        self.mhsa = MyMSA(hidden_d, n_heads)
        self.norm2 = nn.LayerNorm(hidden_d)
        self.mlp = nn.Sequential(
            nn.Linear(hidden_d, mlp_ratio * hidden_d),
            nn.GELU(),
            nn.Linear(mlp_ratio * hidden_d, hidden_d)
        )

    def forward(self, x):
        out = x + self.mhsa(self.norm1(x))
        out = out + self.mlp(self.norm2(out))
        return out


class MyMSA(nn.Module):
    def __init__(self, hidden_d, n_heads):
        super(MyMSA, self).__init__()
        self.hidden_d = hidden_d
        self.n_heads = n_heads

        self.qkv = nn.Linear(hidden_d, hidden_d * 3)
        self.fc = nn.Linear(hidden_d, hidden_d)

    def forward(self, x):
        qkv = self.qkv(x)
        q, k, v = torch.chunk(qkv, 3, dim=-1)

        q = q.view(x.size(0), -1, self.n_heads, self.hidden_d // self.n_heads)
        k = k.view(x.size(0), -1, self.n_heads, self.hidden_d // self.n_heads)
        v = v.view(x.size(0), -1, self.n_heads, self.hidden_d // self.n_heads)

        q = q.transpose(1, 2)
        k = k.transpose(1, 2)
        v = v.transpose(1, 2)

        scores = torch.matmul(q, k.transpose(-2, -1)) / (self.hidden_d // self.n_heads) ** 0.5
        attn = torch.softmax(scores, dim=-1)

        out = torch.matmul(attn, v)
        out = out.transpose(1, 2).contiguous().view(x.size(0), -1, self.hidden_d)

        out = self.fc(out)

        return out


def patchify(images, n_patches):
    n, c, h, w = images.shape

    assert h == w, "Patchify method is implemented for square images only"

    patches = torch.zeros(n, n_patches ** 2, h * w * c // n_patches ** 2)
    patch_size = h // n_patches

    for idx, image in enumerate(images):
        for i in range(n_patches):
            for j in range(n_patches):
                patch = image[:, i * patch_size: (i + 1) * patch_size, j * patch_size: (j + 1) * patch_size]
                patches[idx, i * n_patches + j] = patch.flatten()
    return patches


def get_positional_embeddings(sequence_length, d):
    result = torch.ones(sequence_length, d)
    for i in range(sequence_length):
        for j in range(d):
            result[i][j] = np.sin(i / (10000 ** (j / d))) if j % 2 == 0 else np.cos(i / (10000 ** ((j - 1) / d)))
    return result


if __name__ == '__main__':
    main()
# Out:
# Using device:  cpu
# Training:   0%|                                                                                  | 0/5 [00:00<?, ?it/s]
# Epoch 1 in training:   0%|                                                                     | 0/469 [00:00<?, ?it/s]
# Epoch 1 in training:   0%|▏                                                            | 1/469 [00:00<02:05,  3.74it/s]
# Epoch 1 in training:   0%|▎                                                            | 2/469 [00:00<02:03,  3.77it/s]
# Epoch 1 in training:   1%|▍                                                            | 3/469 [00:00<01:57,  3.96it/s]
# Epoch 1 in training:   1%|▌                                                            | 4/469 [00:01<02:00,  3.86it/s]
# Epoch 1 in training:   1%|▋                                                            | 5/469 [00:01<01:55,  4.03it/s]
# Epoch 1 in training:   1%|▊                                                            | 6/469 [00:01<01:58,  3.89it/s]
# Epoch 1 in training:   1%|▉                                                            | 7/469 [00:01<02:03,  3.75it/s]
# Epoch 1 in training:   2%|█                                                            | 8/469 [00:02<02:09,  3.56it/s]
# Epoch 1 in training:   2%|█▏                                                           | 9/469 [00:02<02:09,  3.54it/s]
# Epoch 1 in training:   2%|█▎                                                          | 10/469 [00:02<02:10,  3.51it/s]
# Epoch 1 in training:   2%|█▍                                                          | 11/469 [00:03<02:11,  3.48it/s]
# Epoch 1 in training:   3%|█▌                                                          | 12/469 [00:03<02:09,  3.53it/s]
# Epoch 1 in training:   3%|█▋                                                          | 13/469 [00:03<02:06,  3.59it/s]
# Epoch 1 in training:   3%|█▊                                                          | 14/469 [00:03<02:03,  3.69it/s]
# Epoch 1 in training:   3%|█▉                                                          | 15/469 [00:04<01:59,  3.79it/s]
# Epoch 1 in training:   3%|██                                                          | 16/469 [00:04<02:00,  3.76it/s]
# Epoch 1 in training:   4%|██▏                                                         | 17/469 [00:04<02:02,  3.70it/s]
# Epoch 1 in training:   4%|██▎                                                         | 18/469 [00:04<02:02,  3.69it/s]
# Epoch 1 in training:   4%|██▍                                                         | 19/469 [00:05<02:00,  3.72it/s]
# Epoch 1 in training:   4%|██▌                                                         | 20/469 [00:05<02:00,  3.71it/s]
# Epoch 1 in training:   4%|██▋                                                         | 21/469 [00:05<01:58,  3.78it/s]
# Epoch 1 in training:   5%|██▊                                                         | 22/469 [00:05<01:57,  3.80it/s]
# Epoch 1 in training:   5%|██▉                                                         | 23/469 [00:06<01:55,  3.86it/s]
# Epoch 1 in training:   5%|███                                                         | 24/469 [00:06<01:59,  3.71it/s]
# Epoch 1 in training:   5%|███▏                                                        | 25/469 [00:06<02:18,  3.21it/s]
# Epoch 1 in training:   6%|███▎                                                        | 26/469 [00:07<02:21,  3.12it/s]
# Epoch 1 in training:   6%|███▍                                                        | 27/469 [00:07<02:27,  3.00it/s]
# Epoch 1 in training:   6%|███▌                                                        | 28/469 [00:07<02:31,  2.92it/s]
# Epoch 1 in training:   6%|███▋                                                        | 29/469 [00:08<02:29,  2.94it/s]
# Epoch 1 in training:   6%|███▊                                                        | 30/469 [00:08<02:31,  2.89it/s]
# Epoch 1 in training:   7%|███▉                                                        | 31/469 [00:08<02:29,  2.93it/s]
# Epoch 1 in training:   7%|████                                                        | 32/469 [00:09<02:28,  2.94it/s]
# Epoch 1 in training:   7%|████▏                                                       | 33/469 [00:09<02:28,  2.94it/s]
# Epoch 1 in training:   7%|████▎                                                       | 34/469 [00:10<02:39,  2.73it/s]
# Epoch 1 in training:   7%|████▍                                                       | 35/469 [00:10<02:49,  2.57it/s]
# Epoch 1 in training:   8%|████▌                                                       | 36/469 [00:10<02:45,  2.62it/s]
# Epoch 1 in training:   8%|████▋                                                       | 37/469 [00:11<02:38,  2.72it/s]
# Epoch 1 in training:   8%|████▊                                                       | 38/469 [00:11<02:33,  2.81it/s]
# Epoch 1 in training:   8%|████▉                                                       | 39/469 [00:11<02:28,  2.90it/s]
# Epoch 1 in training:   9%|█████                                                       | 40/469 [00:12<02:24,  2.97it/s]
# Epoch 1 in training:   9%|█████▏                                                      | 41/469 [00:12<02:21,  3.03it/s]
# Epoch 1 in training:   9%|█████▎                                                      | 42/469 [00:12<02:19,  3.07it/s]
# Epoch 1 in training:   9%|█████▌                                                      | 43/469 [00:13<02:13,  3.19it/s]
# Epoch 1 in training:   9%|█████▋                                                      | 44/469 [00:13<02:09,  3.29it/s]
# Epoch 1 in training:  10%|█████▊                                                      | 45/469 [00:13<02:02,  3.47it/s]
# Epoch 1 in training:  10%|█████▉                                                      | 46/469 [00:13<01:57,  3.61it/s]
# Epoch 1 in training:  10%|██████                                                      | 47/469 [00:14<01:55,  3.65it/s]
# Epoch 1 in training:  10%|██████▏                                                     | 48/469 [00:14<02:00,  3.51it/s]
# Epoch 1 in training:  10%|██████▎                                                     | 49/469 [00:14<01:54,  3.66it/s]
# Epoch 1 in training:  11%|██████▍                                                     | 50/469 [00:14<01:55,  3.62it/s]
# Epoch 1 in training:  11%|██████▌                                                     | 51/469 [00:15<01:53,  3.70it/s]
# Epoch 1 in training:  11%|██████▋                                                     | 52/469 [00:15<02:08,  3.24it/s]
# Epoch 1 in training:  11%|██████▊                                                     | 53/469 [00:15<02:06,  3.30it/s]
# Epoch 1 in training:  12%|██████▉                                                     | 54/469 [00:16<02:45,  2.51it/s]
# Epoch 1 in training:  12%|███████                                                     | 55/469 [00:16<02:34,  2.68it/s]
# Epoch 1 in training:  12%|███████▏                                                    | 56/469 [00:17<02:28,  2.78it/s]
# Epoch 1 in training:  12%|███████▎                                                    | 57/469 [00:17<02:20,  2.93it/s]
# Epoch 1 in training:  12%|███████▍                                                    | 58/469 [00:17<02:26,  2.80it/s]
# Epoch 1 in training:  13%|███████▌                                                    | 59/469 [00:18<02:39,  2.58it/s]
# Epoch 1 in training:  13%|███████▋                                                    | 60/469 [00:18<02:35,  2.63it/s]
# Epoch 1 in training:  13%|███████▊                                                    | 61/469 [00:18<02:22,  2.86it/s]
# Epoch 1 in training:  13%|███████▉                                                    | 62/469 [00:19<02:14,  3.03it/s]
# Epoch 1 in training:  13%|████████                                                    | 63/469 [00:19<02:13,  3.03it/s]
# Epoch 1 in training:  14%|████████▏                                                   | 64/469 [00:19<02:12,  3.07it/s]
# Epoch 1 in training:  14%|████████▎                                                   | 65/469 [00:20<02:05,  3.21it/s]
# Epoch 1 in training:  14%|████████▍                                                   | 66/469 [00:20<02:02,  3.29it/s]
# Epoch 1 in training:  14%|████████▌                                                   | 67/469 [00:20<01:54,  3.51it/s]
# Epoch 1 in training:  14%|████████▋                                                   | 68/469 [00:21<01:54,  3.50it/s]
# Epoch 1 in training:  15%|████████▊                                                   | 69/469 [00:21<01:48,  3.69it/s]
# Epoch 1 in training:  15%|████████▉                                                   | 70/469 [00:21<01:46,  3.74it/s]
# Epoch 1 in training:  15%|█████████                                                   | 71/469 [00:21<01:41,  3.93it/s]
# Epoch 1 in training:  15%|█████████▏                                                  | 72/469 [00:21<01:39,  3.98it/s]
# Epoch 1 in training:  16%|█████████▎                                                  | 73/469 [00:22<01:38,  4.03it/s]
# Epoch 1 in training:  16%|█████████▍                                                  | 74/469 [00:22<01:41,  3.87it/s]
# Epoch 1 in training:  16%|█████████▌                                                  | 75/469 [00:22<01:40,  3.92it/s]
# Epoch 1 in training:  16%|█████████▋                                                  | 76/469 [00:22<01:39,  3.94it/s]
# Epoch 1 in training:  16%|█████████▊                                                  | 77/469 [00:23<01:40,  3.90it/s]
# Epoch 1 in training:  17%|█████████▉                                                  | 78/469 [00:23<01:36,  4.04it/s]
# Epoch 1 in training:  17%|██████████                                                  | 79/469 [00:23<01:35,  4.08it/s]
# Epoch 1 in training:  17%|██████████▏                                                 | 80/469 [00:23<01:33,  4.16it/s]
# Epoch 1 in training:  17%|██████████▎                                                 | 81/469 [00:24<01:33,  4.16it/s]
# Epoch 1 in training:  17%|██████████▍                                                 | 82/469 [00:24<01:35,  4.06it/s]
# Epoch 1 in training:  18%|██████████▌                                                 | 83/469 [00:24<01:34,  4.09it/s]
# Epoch 1 in training:  18%|██████████▋                                                 | 84/469 [00:24<01:36,  4.00it/s]
# Epoch 1 in training:  18%|██████████▊                                                 | 85/469 [00:25<01:36,  3.97it/s]
# Epoch 1 in training:  18%|███████████                                                 | 86/469 [00:25<01:36,  3.96it/s]
# Epoch 1 in training:  19%|███████████▏                                                | 87/469 [00:25<01:37,  3.94it/s]
# Epoch 1 in training:  19%|███████████▎                                                | 88/469 [00:25<01:35,  4.00it/s]
# Epoch 1 in training:  19%|███████████▍                                                | 89/469 [00:26<01:33,  4.07it/s]
# Epoch 1 in training:  19%|███████████▌                                                | 90/469 [00:26<01:31,  4.14it/s]
# Epoch 1 in training:  19%|███████████▋                                                | 91/469 [00:26<01:31,  4.15it/s]
# Epoch 1 in training:  20%|███████████▊                                                | 92/469 [00:26<01:31,  4.10it/s]
# Epoch 1 in training:  20%|███████████▉                                                | 93/469 [00:27<01:32,  4.07it/s]
# Epoch 1 in training:  20%|████████████                                                | 94/469 [00:27<01:30,  4.15it/s]
# Epoch 1 in training:  20%|████████████▏                                               | 95/469 [00:27<01:30,  4.11it/s]
# Epoch 1 in training:  20%|████████████▎                                               | 96/469 [00:27<01:29,  4.19it/s]
# Epoch 1 in training:  21%|████████████▍                                               | 97/469 [00:28<01:30,  4.12it/s]
# Epoch 1 in training:  21%|████████████▌                                               | 98/469 [00:28<01:29,  4.14it/s]
# Epoch 1 in training:  21%|████████████▋                                               | 99/469 [00:28<01:31,  4.05it/s]
# Epoch 1 in training:  21%|████████████▌                                              | 100/469 [00:28<01:31,  4.03it/s]
# Epoch 1 in training:  22%|████████████▋                                              | 101/469 [00:29<01:32,  3.98it/s]
# Epoch 1 in training:  22%|████████████▊                                              | 102/469 [00:29<01:29,  4.08it/s]
# Epoch 1 in training:  22%|████████████▉                                              | 103/469 [00:29<01:30,  4.05it/s]
# Epoch 1 in training:  22%|█████████████                                              | 104/469 [00:29<01:32,  3.93it/s]
# Epoch 1 in training:  22%|█████████████▏                                             | 105/469 [00:30<01:32,  3.95it/s]
# Epoch 1 in training:  23%|█████████████▎                                             | 106/469 [00:30<01:31,  3.97it/s]
# Epoch 1 in training:  23%|█████████████▍                                             | 107/469 [00:30<01:44,  3.48it/s]
# Epoch 1 in training:  23%|█████████████▌                                             | 108/469 [00:31<01:48,  3.34it/s]
# Epoch 1 in training:  23%|█████████████▋                                             | 109/469 [00:31<01:45,  3.41it/s]
# Epoch 1 in training:  23%|█████████████▊                                             | 110/469 [00:31<01:44,  3.44it/s]
# Epoch 1 in training:  24%|█████████████▉                                             | 111/469 [00:31<01:43,  3.45it/s]
# Epoch 1 in training:  24%|██████████████                                             | 112/469 [00:32<01:43,  3.46it/s]
# Epoch 1 in training:  24%|██████████████▏                                            | 113/469 [00:32<01:38,  3.62it/s]
# Epoch 1 in training:  24%|██████████████▎                                            | 114/469 [00:32<01:36,  3.68it/s]
# Epoch 1 in training:  25%|██████████████▍                                            | 115/469 [00:32<01:33,  3.77it/s]
# Epoch 1 in training:  25%|██████████████▌                                            | 116/469 [00:33<01:31,  3.84it/s]
# Epoch 1 in training:  25%|██████████████▋                                            | 117/469 [00:33<01:30,  3.88it/s]
# Epoch 1 in training:  25%|██████████████▊                                            | 118/469 [00:33<01:31,  3.82it/s]
# Epoch 1 in training:  25%|██████████████▉                                            | 119/469 [00:34<01:30,  3.88it/s]
# Epoch 1 in training:  26%|███████████████                                            | 120/469 [00:34<01:31,  3.83it/s]
# Epoch 1 in training:  26%|███████████████▏                                           | 121/469 [00:34<01:30,  3.86it/s]
# Epoch 1 in training:  26%|███████████████▎                                           | 122/469 [00:34<01:29,  3.88it/s]
# Epoch 1 in training:  26%|███████████████▍                                           | 123/469 [00:35<01:27,  3.94it/s]
# Epoch 1 in training:  26%|███████████████▌                                           | 124/469 [00:35<01:29,  3.87it/s]
# Epoch 1 in training:  27%|███████████████▋                                           | 125/469 [00:35<01:28,  3.90it/s]
# Epoch 1 in training:  27%|███████████████▊                                           | 126/469 [00:35<01:34,  3.65it/s]
# Epoch 1 in training:  27%|███████████████▉                                           | 127/469 [00:36<01:39,  3.44it/s]
# Epoch 1 in training:  27%|████████████████                                           | 128/469 [00:36<01:48,  3.15it/s]
# Epoch 1 in training:  28%|████████████████▏                                          | 129/469 [00:36<01:51,  3.04it/s]
# Epoch 1 in training:  28%|████████████████▎                                          | 130/469 [00:37<01:51,  3.03it/s]
# Epoch 1 in training:  28%|████████████████▍                                          | 131/469 [00:37<02:00,  2.81it/s]
# Epoch 1 in training:  28%|████████████████▌                                          | 132/469 [00:37<01:53,  2.97it/s]
# Epoch 1 in training:  28%|████████████████▋                                          | 133/469 [00:38<01:46,  3.15it/s]
# Epoch 1 in training:  29%|████████████████▊                                          | 134/469 [00:38<01:42,  3.26it/s]
# Epoch 1 in training:  29%|████████████████▉                                          | 135/469 [00:38<01:37,  3.42it/s]
# Epoch 1 in training:  29%|█████████████████                                          | 136/469 [00:39<01:34,  3.51it/s]
# Epoch 1 in training:  29%|█████████████████▏                                         | 137/469 [00:39<01:33,  3.54it/s]
# Epoch 1 in training:  29%|█████████████████▎                                         | 138/469 [00:39<01:33,  3.55it/s]
# Epoch 1 in training:  30%|█████████████████▍                                         | 139/469 [00:39<01:30,  3.66it/s]
# Epoch 1 in training:  30%|█████████████████▌                                         | 140/469 [00:40<01:30,  3.64it/s]
# Epoch 1 in training:  30%|█████████████████▋                                         | 141/469 [00:40<01:30,  3.64it/s]
# Epoch 1 in training:  30%|█████████████████▊                                         | 142/469 [00:40<01:30,  3.61it/s]
# Epoch 1 in training:  30%|█████████████████▉                                         | 143/469 [00:40<01:30,  3.60it/s]
# Epoch 1 in training:  31%|██████████████████                                         | 144/469 [00:41<01:30,  3.59it/s]
# Epoch 1 in training:  31%|██████████████████▏                                        | 145/469 [00:41<01:30,  3.57it/s]
# Epoch 1 in training:  31%|██████████████████▎                                        | 146/469 [00:41<01:29,  3.60it/s]
# Epoch 1 in training:  31%|██████████████████▍                                        | 147/469 [00:42<01:27,  3.67it/s]
# Epoch 1 in training:  32%|██████████████████▌                                        | 148/469 [00:42<01:28,  3.62it/s]
# Epoch 1 in training:  32%|██████████████████▋                                        | 149/469 [00:42<01:29,  3.58it/s]
# Epoch 1 in training:  32%|██████████████████▊                                        | 150/469 [00:42<01:27,  3.63it/s]
# Epoch 1 in training:  32%|██████████████████▉                                        | 151/469 [00:43<01:25,  3.70it/s]
# Epoch 1 in training:  32%|███████████████████                                        | 152/469 [00:43<01:25,  3.69it/s]
# Epoch 1 in training:  33%|███████████████████▏                                       | 153/469 [00:43<01:26,  3.64it/s]
# Epoch 1 in training:  33%|███████████████████▎                                       | 154/469 [00:44<01:26,  3.62it/s]
# Epoch 1 in training:  33%|███████████████████▍                                       | 155/469 [00:44<01:25,  3.67it/s]
# Epoch 1 in training:  33%|███████████████████▌                                       | 156/469 [00:44<01:25,  3.67it/s]
# Epoch 1 in training:  33%|███████████████████▊                                       | 157/469 [00:44<01:25,  3.64it/s]
# Epoch 1 in training:  34%|███████████████████▉                                       | 158/469 [00:45<01:23,  3.71it/s]
# Epoch 1 in training:  34%|████████████████████                                       | 159/469 [00:45<01:23,  3.70it/s]
# Epoch 1 in training:  34%|████████████████████▏                                      | 160/469 [00:45<01:25,  3.61it/s]
# Epoch 1 in training:  34%|████████████████████▎                                      | 161/469 [00:45<01:22,  3.71it/s]
# Epoch 1 in training:  35%|████████████████████▍                                      | 162/469 [00:46<01:22,  3.70it/s]
# Epoch 1 in training:  35%|████████████████████▌                                      | 163/469 [00:46<01:21,  3.77it/s]
# Epoch 1 in training:  35%|████████████████████▋                                      | 164/469 [00:46<01:21,  3.75it/s]
# Epoch 1 in training:  35%|████████████████████▊                                      | 165/469 [00:46<01:21,  3.73it/s]
# Epoch 1 in training:  35%|████████████████████▉                                      | 166/469 [00:47<01:19,  3.83it/s]
# Epoch 1 in training:  36%|█████████████████████                                      | 167/469 [00:47<01:19,  3.80it/s]
# Epoch 1 in training:  36%|█████████████████████▏                                     | 168/469 [00:47<01:21,  3.70it/s]
# Epoch 1 in training:  36%|█████████████████████▎                                     | 169/469 [00:48<01:20,  3.73it/s]
# Epoch 1 in training:  36%|█████████████████████▍                                     | 170/469 [00:48<01:18,  3.82it/s]
# Epoch 1 in training:  36%|█████████████████████▌                                     | 171/469 [00:48<01:19,  3.74it/s]
# Epoch 1 in training:  37%|█████████████████████▋                                     | 172/469 [00:48<01:23,  3.56it/s]
# Epoch 1 in training:  37%|█████████████████████▊                                     | 173/469 [00:49<01:30,  3.27it/s]
# Epoch 1 in training:  37%|█████████████████████▉                                     | 174/469 [00:49<01:30,  3.27it/s]
# Epoch 1 in training:  37%|██████████████████████                                     | 175/469 [00:49<01:27,  3.34it/s]
# Epoch 1 in training:  38%|██████████████████████▏                                    | 176/469 [00:50<01:23,  3.49it/s]
# Epoch 1 in training:  38%|██████████████████████▎                                    | 177/469 [00:50<01:31,  3.18it/s]
# Epoch 1 in training:  38%|██████████████████████▍                                    | 178/469 [00:50<01:30,  3.22it/s]
# Epoch 1 in training:  38%|██████████████████████▌                                    | 179/469 [00:51<01:27,  3.32it/s]
# Epoch 1 in training:  38%|██████████████████████▋                                    | 180/469 [00:51<01:27,  3.29it/s]
# Epoch 1 in training:  39%|██████████████████████▊                                    | 181/469 [00:51<01:27,  3.29it/s]
# Epoch 1 in training:  39%|██████████████████████▉                                    | 182/469 [00:51<01:23,  3.45it/s]
# Epoch 1 in training:  39%|███████████████████████                                    | 183/469 [00:52<01:20,  3.54it/s]
# Epoch 1 in training:  39%|███████████████████████▏                                   | 184/469 [00:52<01:19,  3.58it/s]
# Epoch 1 in training:  39%|███████████████████████▎                                   | 185/469 [00:52<01:19,  3.59it/s]
# Epoch 1 in training:  40%|███████████████████████▍                                   | 186/469 [00:52<01:18,  3.60it/s]
# Epoch 1 in training:  40%|███████████████████████▌                                   | 187/469 [00:53<01:15,  3.73it/s]
# Epoch 1 in training:  40%|███████████████████████▋                                   | 188/469 [00:53<01:15,  3.74it/s]
# Epoch 1 in training:  40%|███████████████████████▊                                   | 189/469 [00:53<01:12,  3.85it/s]
# Epoch 1 in training:  41%|███████████████████████▉                                   | 190/469 [00:54<01:12,  3.87it/s]
# Epoch 1 in training:  41%|████████████████████████                                   | 191/469 [00:54<01:10,  3.96it/s]
# Epoch 1 in training:  41%|████████████████████████▏                                  | 192/469 [00:54<01:09,  4.00it/s]
# Epoch 1 in training:  41%|████████████████████████▎                                  | 193/469 [00:54<01:07,  4.09it/s]
# Epoch 1 in training:  41%|████████████████████████▍                                  | 194/469 [00:54<01:09,  3.93it/s]
# Epoch 1 in training:  42%|████████████████████████▌                                  | 195/469 [00:55<01:08,  4.01it/s]
# Epoch 1 in training:  42%|████████████████████████▋                                  | 196/469 [00:55<01:06,  4.08it/s]
# Epoch 1 in training:  42%|████████████████████████▊                                  | 197/469 [00:55<01:07,  4.06it/s]
# Epoch 1 in training:  42%|████████████████████████▉                                  | 198/469 [00:55<01:07,  4.00it/s]
# Epoch 1 in training:  42%|█████████████████████████                                  | 199/469 [00:56<01:07,  3.99it/s]
# Epoch 1 in training:  43%|█████████████████████████▏                                 | 200/469 [00:56<01:07,  3.96it/s]
# Epoch 1 in training:  43%|█████████████████████████▎                                 | 201/469 [00:56<01:07,  3.95it/s]
# Epoch 1 in training:  43%|█████████████████████████▍                                 | 202/469 [00:56<01:06,  3.99it/s]
# Epoch 1 in training:  43%|█████████████████████████▌                                 | 203/469 [00:57<01:06,  4.00it/s]
# Epoch 1 in training:  43%|█████████████████████████▋                                 | 204/469 [00:57<01:06,  3.97it/s]
# Epoch 1 in training:  44%|█████████████████████████▊                                 | 205/469 [00:57<01:05,  4.01it/s]
# Epoch 1 in training:  44%|█████████████████████████▉                                 | 206/469 [00:57<01:06,  3.96it/s]
# Epoch 1 in training:  44%|██████████████████████████                                 | 207/469 [00:58<01:06,  3.93it/s]
# Epoch 1 in training:  44%|██████████████████████████▏                                | 208/469 [00:58<01:05,  3.98it/s]
# Epoch 1 in training:  45%|██████████████████████████▎                                | 209/469 [00:58<01:05,  3.94it/s]
# Epoch 1 in training:  45%|██████████████████████████▍                                | 210/469 [00:59<01:05,  3.93it/s]
# Epoch 1 in training:  45%|██████████████████████████▌                                | 211/469 [00:59<01:06,  3.90it/s]
# Epoch 1 in training:  45%|██████████████████████████▋                                | 212/469 [00:59<01:05,  3.91it/s]
# Epoch 1 in training:  45%|██████████████████████████▊                                | 213/469 [00:59<01:04,  4.00it/s]
# Epoch 1 in training:  46%|██████████████████████████▉                                | 214/469 [01:00<01:03,  4.00it/s]
# Epoch 1 in training:  46%|███████████████████████████                                | 215/469 [01:00<01:04,  3.95it/s]
# Epoch 1 in training:  46%|███████████████████████████▏                               | 216/469 [01:00<01:02,  4.02it/s]
# Epoch 1 in training:  46%|███████████████████████████▎                               | 217/469 [01:00<01:02,  4.02it/s]
# Epoch 1 in training:  46%|███████████████████████████▍                               | 218/469 [01:01<01:02,  3.99it/s]
# Epoch 1 in training:  47%|███████████████████████████▌                               | 219/469 [01:01<01:01,  4.06it/s]
# Epoch 1 in training:  47%|███████████████████████████▋                               | 220/469 [01:01<01:04,  3.86it/s]
# Epoch 1 in training:  47%|███████████████████████████▊                               | 221/469 [01:01<01:08,  3.60it/s]
# Epoch 1 in training:  47%|███████████████████████████▉                               | 222/469 [01:02<01:13,  3.37it/s]
# Epoch 1 in training:  48%|████████████████████████████                               | 223/469 [01:02<01:14,  3.31it/s]
# Epoch 1 in training:  48%|████████████████████████████▏                              | 224/469 [01:02<01:14,  3.29it/s]
# Epoch 1 in training:  48%|████████████████████████████▎                              | 225/469 [01:03<01:15,  3.25it/s]
# Epoch 1 in training:  48%|████████████████████████████▍                              | 226/469 [01:03<01:19,  3.07it/s]
# Epoch 1 in training:  48%|████████████████████████████▌                              | 227/469 [01:03<01:16,  3.16it/s]
# Epoch 1 in training:  49%|████████████████████████████▋                              | 228/469 [01:04<01:11,  3.37it/s]
# Epoch 1 in training:  49%|████████████████████████████▊                              | 229/469 [01:04<01:10,  3.39it/s]
# Epoch 1 in training:  49%|████████████████████████████▉                              | 230/469 [01:04<01:13,  3.25it/s]
# Epoch 1 in training:  49%|█████████████████████████████                              | 231/469 [01:04<01:12,  3.29it/s]
# Epoch 1 in training:  49%|█████████████████████████████▏                             | 232/469 [01:05<01:10,  3.39it/s]
# Epoch 1 in training:  50%|█████████████████████████████▎                             | 233/469 [01:05<01:07,  3.52it/s]
# Epoch 1 in training:  50%|█████████████████████████████▍                             | 234/469 [01:05<01:08,  3.42it/s]
# Epoch 1 in training:  50%|█████████████████████████████▌                             | 235/469 [01:06<01:07,  3.48it/s]
# Epoch 1 in training:  50%|█████████████████████████████▋                             | 236/469 [01:06<01:03,  3.68it/s]
# Epoch 1 in training:  51%|█████████████████████████████▊                             | 237/469 [01:06<01:03,  3.68it/s]
# Epoch 1 in training:  51%|█████████████████████████████▉                             | 238/469 [01:06<01:04,  3.57it/s]
# Epoch 1 in training:  51%|██████████████████████████████                             | 239/469 [01:07<01:06,  3.45it/s]
# Epoch 1 in training:  51%|██████████████████████████████▏                            | 240/469 [01:07<01:06,  3.44it/s]
# Epoch 1 in training:  51%|██████████████████████████████▎                            | 241/469 [01:07<01:02,  3.63it/s]
# Epoch 1 in training:  52%|██████████████████████████████▍                            | 242/469 [01:08<01:03,  3.58it/s]
# Epoch 1 in training:  52%|██████████████████████████████▌                            | 243/469 [01:08<01:00,  3.75it/s]
# Epoch 1 in training:  52%|██████████████████████████████▋                            | 244/469 [01:08<01:00,  3.71it/s]
# Epoch 1 in training:  52%|██████████████████████████████▊                            | 245/469 [01:08<01:00,  3.70it/s]
# Epoch 1 in training:  52%|██████████████████████████████▉                            | 246/469 [01:09<01:02,  3.59it/s]
# Epoch 1 in training:  53%|███████████████████████████████                            | 247/469 [01:09<01:01,  3.59it/s]
# Epoch 1 in training:  53%|███████████████████████████████▏                           | 248/469 [01:09<01:02,  3.56it/s]
# Epoch 1 in training:  53%|███████████████████████████████▎                           | 249/469 [01:09<01:00,  3.67it/s]
# Epoch 1 in training:  53%|███████████████████████████████▍                           | 250/469 [01:10<01:00,  3.63it/s]
# Epoch 1 in training:  54%|███████████████████████████████▌                           | 251/469 [01:10<00:59,  3.69it/s]
# Epoch 1 in training:  54%|███████████████████████████████▋                           | 252/469 [01:10<01:02,  3.49it/s]
# Epoch 1 in training:  54%|███████████████████████████████▊                           | 253/469 [01:11<01:00,  3.55it/s]
# Epoch 1 in training:  54%|███████████████████████████████▉                           | 254/469 [01:11<00:58,  3.67it/s]
# Epoch 1 in training:  54%|████████████████████████████████                           | 255/469 [01:11<00:58,  3.65it/s]
# Epoch 1 in training:  55%|████████████████████████████████▏                          | 256/469 [01:11<00:56,  3.75it/s]
# Epoch 1 in training:  55%|████████████████████████████████▎                          | 257/469 [01:12<00:55,  3.79it/s]
# Epoch 1 in training:  55%|████████████████████████████████▍                          | 258/469 [01:12<00:56,  3.75it/s]
# Epoch 1 in training:  55%|████████████████████████████████▌                          | 259/469 [01:12<00:56,  3.69it/s]
# Epoch 1 in training:  55%|████████████████████████████████▋                          | 260/469 [01:12<00:57,  3.65it/s]
# Epoch 1 in training:  56%|████████████████████████████████▊                          | 261/469 [01:13<00:56,  3.70it/s]
# Epoch 1 in training:  56%|████████████████████████████████▉                          | 262/469 [01:13<00:54,  3.78it/s]
# Epoch 1 in training:  56%|█████████████████████████████████                          | 263/469 [01:13<00:53,  3.83it/s]
# Epoch 1 in training:  56%|█████████████████████████████████▏                         | 264/469 [01:13<00:52,  3.87it/s]
# Epoch 1 in training:  57%|█████████████████████████████████▎                         | 265/469 [01:14<00:53,  3.84it/s]
# Epoch 1 in training:  57%|█████████████████████████████████▍                         | 266/469 [01:14<00:52,  3.84it/s]
# Epoch 1 in training:  57%|█████████████████████████████████▌                         | 267/469 [01:14<00:53,  3.81it/s]
# Epoch 1 in training:  57%|█████████████████████████████████▋                         | 268/469 [01:15<00:52,  3.86it/s]
# Epoch 1 in training:  57%|█████████████████████████████████▊                         | 269/469 [01:15<00:50,  3.95it/s]
# Epoch 1 in training:  58%|█████████████████████████████████▉                         | 270/469 [01:15<00:49,  3.98it/s]
# Epoch 1 in training:  58%|██████████████████████████████████                         | 271/469 [01:15<00:49,  3.96it/s]
# Epoch 1 in training:  58%|██████████████████████████████████▏                        | 272/469 [01:16<00:50,  3.88it/s]
# Epoch 1 in training:  58%|██████████████████████████████████▎                        | 273/469 [01:16<00:50,  3.90it/s]
# Epoch 1 in training:  58%|██████████████████████████████████▍                        | 274/469 [01:16<00:50,  3.85it/s]
# Epoch 1 in training:  59%|██████████████████████████████████▌                        | 275/469 [01:16<00:51,  3.74it/s]
# Epoch 1 in training:  59%|██████████████████████████████████▋                        | 276/469 [01:17<01:02,  3.07it/s]
# Epoch 1 in training:  59%|██████████████████████████████████▊                        | 277/469 [01:18<01:24,  2.26it/s]
# Epoch 1 in training:  59%|██████████████████████████████████▉                        | 278/469 [01:18<01:15,  2.54it/s]
# Epoch 1 in training:  59%|███████████████████████████████████                        | 279/469 [01:18<01:09,  2.75it/s]
# Epoch 1 in training:  60%|███████████████████████████████████▏                       | 280/469 [01:18<01:03,  2.96it/s]
# Epoch 1 in training:  60%|███████████████████████████████████▎                       | 281/469 [01:19<00:59,  3.15it/s]
# Epoch 1 in training:  60%|███████████████████████████████████▍                       | 282/469 [01:19<00:55,  3.35it/s]
# Epoch 1 in training:  60%|███████████████████████████████████▌                       | 283/469 [01:19<00:54,  3.44it/s]
# Epoch 1 in training:  61%|███████████████████████████████████▋                       | 284/469 [01:19<00:51,  3.57it/s]
# Epoch 1 in training:  61%|███████████████████████████████████▊                       | 285/469 [01:20<00:49,  3.69it/s]
# Epoch 1 in training:  61%|███████████████████████████████████▉                       | 286/469 [01:20<00:48,  3.77it/s]
# Epoch 1 in training:  61%|████████████████████████████████████                       | 287/469 [01:20<00:48,  3.72it/s]
# Epoch 1 in training:  61%|████████████████████████████████████▏                      | 288/469 [01:20<00:47,  3.79it/s]
# Epoch 1 in training:  62%|████████████████████████████████████▎                      | 289/469 [01:21<00:47,  3.81it/s]
# Epoch 1 in training:  62%|████████████████████████████████████▍                      | 290/469 [01:21<00:46,  3.87it/s]
# Epoch 1 in training:  62%|████████████████████████████████████▌                      | 291/469 [01:21<00:50,  3.51it/s]
# Epoch 1 in training:  62%|████████████████████████████████████▋                      | 292/469 [01:22<00:50,  3.53it/s]
# Epoch 1 in training:  62%|████████████████████████████████████▊                      | 293/469 [01:22<00:49,  3.52it/s]
# Epoch 1 in training:  63%|████████████████████████████████████▉                      | 294/469 [01:22<00:52,  3.36it/s]
# Epoch 1 in training:  63%|█████████████████████████████████████                      | 295/469 [01:22<00:49,  3.53it/s]
# Epoch 1 in training:  63%|█████████████████████████████████████▏                     | 296/469 [01:23<00:47,  3.61it/s]
# Epoch 1 in training:  63%|█████████████████████████████████████▎                     | 297/469 [01:23<00:53,  3.21it/s]
# Epoch 1 in training:  64%|█████████████████████████████████████▍                     | 298/469 [01:23<00:55,  3.10it/s]
# Epoch 1 in training:  64%|█████████████████████████████████████▌                     | 299/469 [01:24<00:55,  3.08it/s]
# Epoch 1 in training:  64%|█████████████████████████████████████▋                     | 300/469 [01:24<00:57,  2.93it/s]
# Epoch 1 in training:  64%|█████████████████████████████████████▊                     | 301/469 [01:24<00:56,  2.99it/s]
# Epoch 1 in training:  64%|█████████████████████████████████████▉                     | 302/469 [01:25<00:51,  3.23it/s]
# Epoch 1 in training:  65%|██████████████████████████████████████                     | 303/469 [01:25<00:47,  3.47it/s]
# Epoch 1 in training:  65%|██████████████████████████████████████▏                    | 304/469 [01:25<00:45,  3.63it/s]
# Epoch 1 in training:  65%|██████████████████████████████████████▎                    | 305/469 [01:25<00:42,  3.86it/s]
# Epoch 1 in training:  65%|██████████████████████████████████████▍                    | 306/469 [01:26<00:41,  3.92it/s]
# Epoch 1 in training:  65%|██████████████████████████████████████▌                    | 307/469 [01:26<00:39,  4.05it/s]
# Epoch 1 in training:  66%|██████████████████████████████████████▋                    | 308/469 [01:26<00:40,  4.01it/s]
# Epoch 1 in training:  66%|██████████████████████████████████████▊                    | 309/469 [01:26<00:40,  3.98it/s]
# Epoch 1 in training:  66%|██████████████████████████████████████▉                    | 310/469 [01:27<00:38,  4.08it/s]
# Epoch 1 in training:  66%|███████████████████████████████████████                    | 311/469 [01:27<00:38,  4.07it/s]
# Epoch 1 in training:  67%|███████████████████████████████████████▏                   | 312/469 [01:27<00:39,  3.94it/s]
# Epoch 1 in training:  67%|███████████████████████████████████████▍                   | 313/469 [01:27<00:42,  3.65it/s]
# Epoch 1 in training:  67%|███████████████████████████████████████▌                   | 314/469 [01:28<00:41,  3.69it/s]
# Epoch 1 in training:  67%|███████████████████████████████████████▋                   | 315/469 [01:28<00:40,  3.79it/s]
# Epoch 1 in training:  67%|███████████████████████████████████████▊                   | 316/469 [01:28<00:39,  3.90it/s]
# Epoch 1 in training:  68%|███████████████████████████████████████▉                   | 317/469 [01:28<00:38,  3.94it/s]
# Epoch 1 in training:  68%|████████████████████████████████████████                   | 318/469 [01:29<00:38,  3.94it/s]
# Epoch 1 in training:  68%|████████████████████████████████████████▏                  | 319/469 [01:29<00:39,  3.82it/s]
# Epoch 1 in training:  68%|████████████████████████████████████████▎                  | 320/469 [01:29<00:39,  3.82it/s]
# Epoch 1 in training:  68%|████████████████████████████████████████▍                  | 321/469 [01:30<00:39,  3.79it/s]
# Epoch 1 in training:  69%|████████████████████████████████████████▌                  | 322/469 [01:30<00:38,  3.79it/s]
# Epoch 1 in training:  69%|████████████████████████████████████████▋                  | 323/469 [01:30<00:37,  3.89it/s]
# Epoch 1 in training:  69%|████████████████████████████████████████▊                  | 324/469 [01:30<00:37,  3.89it/s]
# Epoch 1 in training:  69%|████████████████████████████████████████▉                  | 325/469 [01:31<00:36,  3.94it/s]
# Epoch 1 in training:  70%|█████████████████████████████████████████                  | 326/469 [01:31<00:36,  3.97it/s]
# Epoch 1 in training:  70%|█████████████████████████████████████████▏                 | 327/469 [01:31<00:35,  3.98it/s]
# Epoch 1 in training:  70%|█████████████████████████████████████████▎                 | 328/469 [01:31<00:34,  4.05it/s]
# Epoch 1 in training:  70%|█████████████████████████████████████████▍                 | 329/469 [01:32<00:34,  4.04it/s]
# Epoch 1 in training:  70%|█████████████████████████████████████████▌                 | 330/469 [01:32<00:34,  4.07it/s]
# Epoch 1 in training:  71%|█████████████████████████████████████████▋                 | 331/469 [01:32<00:33,  4.13it/s]
# Epoch 1 in training:  71%|█████████████████████████████████████████▊                 | 332/469 [01:32<00:34,  3.94it/s]
# Epoch 1 in training:  71%|█████████████████████████████████████████▉                 | 333/469 [01:33<00:34,  3.90it/s]
# Epoch 1 in training:  71%|██████████████████████████████████████████                 | 334/469 [01:33<00:35,  3.85it/s]
# Epoch 1 in training:  71%|██████████████████████████████████████████▏                | 335/469 [01:33<00:34,  3.91it/s]
# Epoch 1 in training:  72%|██████████████████████████████████████████▎                | 336/469 [01:33<00:34,  3.86it/s]
# Epoch 1 in training:  72%|██████████████████████████████████████████▍                | 337/469 [01:34<00:34,  3.87it/s]
# Epoch 1 in training:  72%|██████████████████████████████████████████▌                | 338/469 [01:34<00:34,  3.85it/s]
# Epoch 1 in training:  72%|██████████████████████████████████████████▋                | 339/469 [01:34<00:32,  3.96it/s]
# Epoch 1 in training:  72%|██████████████████████████████████████████▊                | 340/469 [01:34<00:32,  3.94it/s]
# Epoch 1 in training:  73%|██████████████████████████████████████████▉                | 341/469 [01:35<00:32,  3.92it/s]
# Epoch 1 in training:  73%|███████████████████████████████████████████                | 342/469 [01:35<00:32,  3.90it/s]
# Epoch 1 in training:  73%|███████████████████████████████████████████▏               | 343/469 [01:35<00:33,  3.80it/s]
# Epoch 1 in training:  73%|███████████████████████████████████████████▎               | 344/469 [01:35<00:32,  3.80it/s]
# Epoch 1 in training:  74%|███████████████████████████████████████████▍               | 345/469 [01:36<00:32,  3.86it/s]
# Epoch 1 in training:  74%|███████████████████████████████████████████▌               | 346/469 [01:36<00:31,  3.86it/s]
# Epoch 1 in training:  74%|███████████████████████████████████████████▋               | 347/469 [01:36<00:32,  3.78it/s]
# Epoch 1 in training:  74%|███████████████████████████████████████████▊               | 348/469 [01:36<00:31,  3.83it/s]
# Epoch 1 in training:  74%|███████████████████████████████████████████▉               | 349/469 [01:37<00:30,  3.88it/s]
# Epoch 1 in training:  75%|████████████████████████████████████████████               | 350/469 [01:37<00:31,  3.72it/s]
# Epoch 1 in training:  75%|████████████████████████████████████████████▏              | 351/469 [01:37<00:31,  3.73it/s]
# Epoch 1 in training:  75%|████████████████████████████████████████████▎              | 352/469 [01:38<00:31,  3.67it/s]
# Epoch 1 in training:  75%|████████████████████████████████████████████▍              | 353/469 [01:38<00:31,  3.74it/s]
# Epoch 1 in training:  75%|████████████████████████████████████████████▌              | 354/469 [01:38<00:30,  3.75it/s]
# Epoch 1 in training:  76%|████████████████████████████████████████████▋              | 355/469 [01:38<00:29,  3.82it/s]
# Epoch 1 in training:  76%|████████████████████████████████████████████▊              | 356/469 [01:39<00:29,  3.89it/s]
# Epoch 1 in training:  76%|████████████████████████████████████████████▉              | 357/469 [01:39<00:28,  3.90it/s]
# Epoch 1 in training:  76%|█████████████████████████████████████████████              | 358/469 [01:39<00:29,  3.80it/s]
# Epoch 1 in training:  77%|█████████████████████████████████████████████▏             | 359/469 [01:39<00:29,  3.72it/s]
# Epoch 1 in training:  77%|█████████████████████████████████████████████▎             | 360/469 [01:40<00:34,  3.19it/s]
# Epoch 1 in training:  77%|█████████████████████████████████████████████▍             | 361/469 [01:40<00:33,  3.26it/s]
# Epoch 1 in training:  77%|█████████████████████████████████████████████▌             | 362/469 [01:40<00:32,  3.31it/s]
# Epoch 1 in training:  77%|█████████████████████████████████████████████▋             | 363/469 [01:41<00:30,  3.44it/s]
# Epoch 1 in training:  78%|█████████████████████████████████████████████▊             | 364/469 [01:41<00:29,  3.61it/s]
# Epoch 1 in training:  78%|█████████████████████████████████████████████▉             | 365/469 [01:41<00:31,  3.31it/s]
# Epoch 1 in training:  78%|██████████████████████████████████████████████             | 366/469 [01:42<00:29,  3.45it/s]
# Epoch 1 in training:  78%|██████████████████████████████████████████████▏            | 367/469 [01:42<00:28,  3.54it/s]
# Epoch 1 in training:  78%|██████████████████████████████████████████████▎            | 368/469 [01:42<00:27,  3.63it/s]
# Epoch 1 in training:  79%|██████████████████████████████████████████████▍            | 369/469 [01:42<00:27,  3.68it/s]
# Epoch 1 in training:  79%|██████████████████████████████████████████████▌            | 370/469 [01:43<00:26,  3.69it/s]
# Epoch 1 in training:  79%|██████████████████████████████████████████████▋            | 371/469 [01:43<00:26,  3.66it/s]
# Epoch 1 in training:  79%|██████████████████████████████████████████████▊            | 372/469 [01:43<00:27,  3.56it/s]
# Epoch 1 in training:  80%|██████████████████████████████████████████████▉            | 373/469 [01:43<00:26,  3.64it/s]
# Epoch 1 in training:  80%|███████████████████████████████████████████████            | 374/469 [01:44<00:25,  3.71it/s]
# Epoch 1 in training:  80%|███████████████████████████████████████████████▏           | 375/469 [01:44<00:25,  3.63it/s]
# Epoch 1 in training:  80%|███████████████████████████████████████████████▎           | 376/469 [01:44<00:25,  3.66it/s]
# Epoch 1 in training:  80%|███████████████████████████████████████████████▍           | 377/469 [01:45<00:26,  3.45it/s]
# Epoch 1 in training:  81%|███████████████████████████████████████████████▌           | 378/469 [01:45<00:26,  3.41it/s]
# Epoch 1 in training:  81%|███████████████████████████████████████████████▋           | 379/469 [01:45<00:24,  3.61it/s]
# Epoch 1 in training:  81%|███████████████████████████████████████████████▊           | 380/469 [01:45<00:24,  3.63it/s]
# Epoch 1 in training:  81%|███████████████████████████████████████████████▉           | 381/469 [01:46<00:24,  3.62it/s]
# Epoch 1 in training:  81%|████████████████████████████████████████████████           | 382/469 [01:46<00:25,  3.42it/s]
# Epoch 1 in training:  82%|████████████████████████████████████████████████▏          | 383/469 [01:46<00:24,  3.47it/s]
# Epoch 1 in training:  82%|████████████████████████████████████████████████▎          | 384/469 [01:47<00:24,  3.50it/s]
# Epoch 1 in training:  82%|████████████████████████████████████████████████▍          | 385/469 [01:47<00:24,  3.42it/s]
# Epoch 1 in training:  82%|████████████████████████████████████████████████▌          | 386/469 [01:47<00:24,  3.40it/s]
# Epoch 1 in training:  83%|████████████████████████████████████████████████▋          | 387/469 [01:47<00:23,  3.53it/s]
# Epoch 1 in training:  83%|████████████████████████████████████████████████▊          | 388/469 [01:48<00:24,  3.31it/s]
# Epoch 1 in training:  83%|████████████████████████████████████████████████▉          | 389/469 [01:48<00:27,  2.87it/s]
# Epoch 1 in training:  83%|█████████████████████████████████████████████████          | 390/469 [01:49<00:27,  2.91it/s]
# Epoch 1 in training:  83%|█████████████████████████████████████████████████▏         | 391/469 [01:49<00:29,  2.68it/s]
# Epoch 1 in training:  84%|█████████████████████████████████████████████████▎         | 392/469 [01:49<00:26,  2.85it/s]
# Epoch 1 in training:  84%|█████████████████████████████████████████████████▍         | 393/469 [01:50<00:26,  2.92it/s]
# Epoch 1 in training:  84%|█████████████████████████████████████████████████▌         | 394/469 [01:50<00:23,  3.13it/s]
# Epoch 1 in training:  84%|█████████████████████████████████████████████████▋         | 395/469 [01:50<00:23,  3.14it/s]
# Epoch 1 in training:  84%|█████████████████████████████████████████████████▊         | 396/469 [01:50<00:22,  3.21it/s]
# Epoch 1 in training:  85%|█████████████████████████████████████████████████▉         | 397/469 [01:51<00:25,  2.86it/s]
# ...
# Epoch 5 in training:  73%|███████████████████████████████████████████                | 342/469 [01:43<00:36,  3.51it/s]
# Epoch 5 in training:  73%|███████████████████████████████████████████▏               | 343/469 [01:43<00:34,  3.69it/s]
# Epoch 5 in training:  73%|███████████████████████████████████████████▎               | 344/469 [01:43<00:34,  3.60it/s]
# Epoch 5 in training:  74%|███████████████████████████████████████████▍               | 345/469 [01:43<00:35,  3.53it/s]
# Epoch 5 in training:  74%|███████████████████████████████████████████▌               | 346/469 [01:44<00:34,  3.56it/s]
# Epoch 5 in training:  74%|███████████████████████████████████████████▋               | 347/469 [01:44<00:34,  3.54it/s]
# Epoch 5 in training:  74%|███████████████████████████████████████████▊               | 348/469 [01:44<00:34,  3.55it/s]
# Epoch 5 in training:  74%|███████████████████████████████████████████▉               | 349/469 [01:45<00:33,  3.61it/s]
# Epoch 5 in training:  75%|████████████████████████████████████████████               | 350/469 [01:45<00:31,  3.78it/s]
# Epoch 5 in training:  75%|████████████████████████████████████████████▏              | 351/469 [01:45<00:30,  3.86it/s]
# Epoch 5 in training:  75%|████████████████████████████████████████████▎              | 352/469 [01:45<00:30,  3.84it/s]
# Epoch 5 in training:  75%|████████████████████████████████████████████▍              | 353/469 [01:46<00:29,  3.98it/s]
# Epoch 5 in training:  75%|████████████████████████████████████████████▌              | 354/469 [01:46<00:28,  4.06it/s]
# Epoch 5 in training:  76%|████████████████████████████████████████████▋              | 355/469 [01:46<00:27,  4.18it/s]
# Epoch 5 in training:  76%|████████████████████████████████████████████▊              | 356/469 [01:46<00:27,  4.15it/s]
# Epoch 5 in training:  76%|████████████████████████████████████████████▉              | 357/469 [01:46<00:26,  4.23it/s]
# Epoch 5 in training:  76%|█████████████████████████████████████████████              | 358/469 [01:47<00:26,  4.12it/s]
# Epoch 5 in training:  77%|█████████████████████████████████████████████▏             | 359/469 [01:47<00:26,  4.17it/s]
# Epoch 5 in training:  77%|█████████████████████████████████████████████▎             | 360/469 [01:47<00:26,  4.19it/s]
# Epoch 5 in training:  77%|█████████████████████████████████████████████▍             | 361/469 [01:47<00:26,  4.12it/s]
# Epoch 5 in training:  77%|█████████████████████████████████████████████▌             | 362/469 [01:48<00:26,  4.00it/s]
# Epoch 5 in training:  77%|█████████████████████████████████████████████▋             | 363/469 [01:48<00:25,  4.11it/s]
# Epoch 5 in training:  78%|█████████████████████████████████████████████▊             | 364/469 [01:48<00:25,  4.13it/s]
# Epoch 5 in training:  78%|█████████████████████████████████████████████▉             | 365/469 [01:48<00:24,  4.27it/s]
# Epoch 5 in training:  78%|██████████████████████████████████████████████             | 366/469 [01:49<00:24,  4.17it/s]
# Epoch 5 in training:  78%|██████████████████████████████████████████████▏            | 367/469 [01:49<00:24,  4.22it/s]
# Epoch 5 in training:  78%|██████████████████████████████████████████████▎            | 368/469 [01:49<00:23,  4.24it/s]
# Epoch 5 in training:  79%|██████████████████████████████████████████████▍            | 369/469 [01:49<00:23,  4.26it/s]
# Epoch 5 in training:  79%|██████████████████████████████████████████████▌            | 370/469 [01:50<00:22,  4.33it/s]
# Epoch 5 in training:  79%|██████████████████████████████████████████████▋            | 371/469 [01:50<00:22,  4.36it/s]
# Epoch 5 in training:  79%|██████████████████████████████████████████████▊            | 372/469 [01:50<00:22,  4.35it/s]
# Epoch 5 in training:  80%|██████████████████████████████████████████████▉            | 373/469 [01:50<00:21,  4.38it/s]
# Epoch 5 in training:  80%|███████████████████████████████████████████████            | 374/469 [01:50<00:21,  4.43it/s]
# Epoch 5 in training:  80%|███████████████████████████████████████████████▏           | 375/469 [01:51<00:21,  4.37it/s]
# Epoch 5 in training:  80%|███████████████████████████████████████████████▎           | 376/469 [01:51<00:21,  4.30it/s]
# Epoch 5 in training:  80%|███████████████████████████████████████████████▍           | 377/469 [01:51<00:21,  4.19it/s]
# Epoch 5 in training:  81%|███████████████████████████████████████████████▌           | 378/469 [01:51<00:21,  4.22it/s]
# Epoch 5 in training:  81%|███████████████████████████████████████████████▋           | 379/469 [01:52<00:21,  4.26it/s]
# Epoch 5 in training:  81%|███████████████████████████████████████████████▊           | 380/469 [01:52<00:20,  4.27it/s]
# Epoch 5 in training:  81%|███████████████████████████████████████████████▉           | 381/469 [01:52<00:21,  4.11it/s]
# Epoch 5 in training:  81%|████████████████████████████████████████████████           | 382/469 [01:52<00:22,  3.82it/s]
# Epoch 5 in training:  82%|████████████████████████████████████████████████▏          | 383/469 [01:53<00:22,  3.79it/s]
# Epoch 5 in training:  82%|████████████████████████████████████████████████▎          | 384/469 [01:53<00:22,  3.74it/s]
# Epoch 5 in training:  82%|████████████████████████████████████████████████▍          | 385/469 [01:53<00:22,  3.70it/s]
# Epoch 5 in training:  82%|████████████████████████████████████████████████▌          | 386/469 [01:54<00:22,  3.66it/s]
# Epoch 5 in training:  83%|████████████████████████████████████████████████▋          | 387/469 [01:54<00:22,  3.57it/s]
# Epoch 5 in training:  83%|████████████████████████████████████████████████▊          | 388/469 [01:54<00:22,  3.54it/s]
# Epoch 5 in training:  83%|████████████████████████████████████████████████▉          | 389/469 [01:54<00:22,  3.62it/s]
# Epoch 5 in training:  83%|█████████████████████████████████████████████████          | 390/469 [01:55<00:22,  3.58it/s]
# Epoch 5 in training:  83%|█████████████████████████████████████████████████▏         | 391/469 [01:55<00:20,  3.80it/s]
# Epoch 5 in training:  84%|█████████████████████████████████████████████████▎         | 392/469 [01:55<00:19,  3.94it/s]
# Epoch 5 in training:  84%|█████████████████████████████████████████████████▍         | 393/469 [01:55<00:19,  3.96it/s]
# Epoch 5 in training:  84%|█████████████████████████████████████████████████▌         | 394/469 [01:56<00:19,  3.84it/s]
# Epoch 5 in training:  84%|█████████████████████████████████████████████████▋         | 395/469 [01:56<00:18,  3.94it/s]
# Epoch 5 in training:  84%|█████████████████████████████████████████████████▊         | 396/469 [01:56<00:17,  4.07it/s]
# Epoch 5 in training:  85%|█████████████████████████████████████████████████▉         | 397/469 [01:56<00:17,  4.09it/s]
# Epoch 5 in training:  85%|██████████████████████████████████████████████████         | 398/469 [01:57<00:16,  4.20it/s]
# Epoch 5 in training:  85%|██████████████████████████████████████████████████▏        | 399/469 [01:57<00:16,  4.23it/s]
# Epoch 5 in training:  85%|██████████████████████████████████████████████████▎        | 400/469 [01:57<00:15,  4.38it/s]
# Epoch 5 in training:  86%|██████████████████████████████████████████████████▍        | 401/469 [01:57<00:16,  4.16it/s]
# Epoch 5 in training:  86%|██████████████████████████████████████████████████▌        | 402/469 [01:58<00:15,  4.30it/s]
# Epoch 5 in training:  86%|██████████████████████████████████████████████████▋        | 403/469 [01:58<00:15,  4.13it/s]
# Epoch 5 in training:  86%|██████████████████████████████████████████████████▊        | 404/469 [01:58<00:15,  4.27it/s]
# Epoch 5 in training:  86%|██████████████████████████████████████████████████▉        | 405/469 [01:58<00:15,  4.26it/s]
# Epoch 5 in training:  87%|███████████████████████████████████████████████████        | 406/469 [01:59<00:14,  4.24it/s]
# Epoch 5 in training:  87%|███████████████████████████████████████████████████▏       | 407/469 [01:59<00:14,  4.30it/s]
# Epoch 5 in training:  87%|███████████████████████████████████████████████████▎       | 408/469 [01:59<00:14,  4.35it/s]
# Epoch 5 in training:  87%|███████████████████████████████████████████████████▍       | 409/469 [01:59<00:13,  4.31it/s]
# Epoch 5 in training:  87%|███████████████████████████████████████████████████▌       | 410/469 [01:59<00:13,  4.33it/s]
# Epoch 5 in training:  88%|███████████████████████████████████████████████████▋       | 411/469 [02:00<00:13,  4.43it/s]
# Epoch 5 in training:  88%|███████████████████████████████████████████████████▊       | 412/469 [02:00<00:12,  4.47it/s]
# Epoch 5 in training:  88%|███████████████████████████████████████████████████▉       | 413/469 [02:00<00:12,  4.50it/s]
# Epoch 5 in training:  88%|████████████████████████████████████████████████████       | 414/469 [02:00<00:12,  4.48it/s]
# Epoch 5 in training:  88%|████████████████████████████████████████████████████▏      | 415/469 [02:01<00:12,  4.38it/s]
# Epoch 5 in training:  89%|████████████████████████████████████████████████████▎      | 416/469 [02:01<00:11,  4.43it/s]
# Epoch 5 in training:  89%|████████████████████████████████████████████████████▍      | 417/469 [02:01<00:11,  4.47it/s]
# Epoch 5 in training:  89%|████████████████████████████████████████████████████▌      | 418/469 [02:01<00:11,  4.47it/s]
# Epoch 5 in training:  89%|████████████████████████████████████████████████████▋      | 419/469 [02:01<00:11,  4.46it/s]
# Epoch 5 in training:  90%|████████████████████████████████████████████████████▊      | 420/469 [02:02<00:11,  4.44it/s]
# Epoch 5 in training:  90%|████████████████████████████████████████████████████▉      | 421/469 [02:02<00:11,  4.24it/s]
# Epoch 5 in training:  90%|█████████████████████████████████████████████████████      | 422/469 [02:02<00:11,  4.24it/s]
# Epoch 5 in training:  90%|█████████████████████████████████████████████████████▏     | 423/469 [02:02<00:10,  4.37it/s]
# Epoch 5 in training:  90%|█████████████████████████████████████████████████████▎     | 424/469 [02:03<00:10,  4.30it/s]
# Epoch 5 in training:  91%|█████████████████████████████████████████████████████▍     | 425/469 [02:03<00:10,  4.33it/s]
# Epoch 5 in training:  91%|█████████████████████████████████████████████████████▌     | 426/469 [02:03<00:10,  4.13it/s]
# Epoch 5 in training:  91%|█████████████████████████████████████████████████████▋     | 427/469 [02:03<00:09,  4.20it/s]
# Epoch 5 in training:  91%|█████████████████████████████████████████████████████▊     | 428/469 [02:04<00:09,  4.16it/s]
# Epoch 5 in training:  91%|█████████████████████████████████████████████████████▉     | 429/469 [02:04<00:09,  4.28it/s]
# Epoch 5 in training:  92%|██████████████████████████████████████████████████████     | 430/469 [02:04<00:09,  4.16it/s]
# Epoch 5 in training:  92%|██████████████████████████████████████████████████████▏    | 431/469 [02:04<00:09,  4.11it/s]
# Epoch 5 in training:  92%|██████████████████████████████████████████████████████▎    | 432/469 [02:05<00:09,  4.04it/s]
# Epoch 5 in training:  92%|██████████████████████████████████████████████████████▍    | 433/469 [02:05<00:08,  4.00it/s]
# Epoch 5 in training:  93%|██████████████████████████████████████████████████████▌    | 434/469 [02:05<00:08,  3.95it/s]
# Epoch 5 in training:  93%|██████████████████████████████████████████████████████▋    | 435/469 [02:05<00:08,  3.97it/s]
# Epoch 5 in training:  93%|██████████████████████████████████████████████████████▊    | 436/469 [02:06<00:08,  4.03it/s]
# Epoch 5 in training:  93%|██████████████████████████████████████████████████████▉    | 437/469 [02:06<00:08,  3.78it/s]
# Epoch 5 in training:  93%|███████████████████████████████████████████████████████    | 438/469 [02:06<00:08,  3.77it/s]
# Epoch 5 in training:  94%|███████████████████████████████████████████████████████▏   | 439/469 [02:06<00:08,  3.65it/s]
# Epoch 5 in training:  94%|███████████████████████████████████████████████████████▎   | 440/469 [02:07<00:08,  3.56it/s]
# Epoch 5 in training:  94%|███████████████████████████████████████████████████████▍   | 441/469 [02:07<00:07,  3.55it/s]
# Epoch 5 in training:  94%|███████████████████████████████████████████████████████▌   | 442/469 [02:07<00:07,  3.50it/s]
# Epoch 5 in training:  94%|███████████████████████████████████████████████████████▋   | 443/469 [02:08<00:07,  3.70it/s]
# Epoch 5 in training:  95%|███████████████████████████████████████████████████████▊   | 444/469 [02:08<00:06,  3.86it/s]
# Epoch 5 in training:  95%|███████████████████████████████████████████████████████▉   | 445/469 [02:08<00:06,  3.94it/s]
# Epoch 5 in training:  95%|████████████████████████████████████████████████████████   | 446/469 [02:08<00:05,  4.00it/s]
# Epoch 5 in training:  95%|████████████████████████████████████████████████████████▏  | 447/469 [02:09<00:05,  4.00it/s]
# Epoch 5 in training:  96%|████████████████████████████████████████████████████████▎  | 448/469 [02:09<00:05,  4.18it/s]
# Epoch 5 in training:  96%|████████████████████████████████████████████████████████▍  | 449/469 [02:09<00:04,  4.27it/s]
# Epoch 5 in training:  96%|████████████████████████████████████████████████████████▌  | 450/469 [02:09<00:04,  4.18it/s]
# Epoch 5 in training:  96%|████████████████████████████████████████████████████████▋  | 451/469 [02:09<00:04,  4.31it/s]
# Epoch 5 in training:  96%|████████████████████████████████████████████████████████▊  | 452/469 [02:10<00:03,  4.30it/s]
# Epoch 5 in training:  97%|████████████████████████████████████████████████████████▉  | 453/469 [02:10<00:03,  4.39it/s]
# Epoch 5 in training:  97%|█████████████████████████████████████████████████████████  | 454/469 [02:10<00:03,  4.26it/s]
# Epoch 5 in training:  97%|█████████████████████████████████████████████████████████▏ | 455/469 [02:10<00:03,  4.27it/s]
# Epoch 5 in training:  97%|█████████████████████████████████████████████████████████▎ | 456/469 [02:11<00:03,  4.15it/s]
# Epoch 5 in training:  97%|█████████████████████████████████████████████████████████▍ | 457/469 [02:11<00:02,  4.19it/s]
# Epoch 5 in training:  98%|█████████████████████████████████████████████████████████▌ | 458/469 [02:11<00:02,  4.22it/s]
# Epoch 5 in training:  98%|█████████████████████████████████████████████████████████▋ | 459/469 [02:11<00:02,  4.08it/s]
# Epoch 5 in training:  98%|█████████████████████████████████████████████████████████▊ | 460/469 [02:12<00:02,  4.04it/s]
# Epoch 5 in training:  98%|█████████████████████████████████████████████████████████▉ | 461/469 [02:12<00:01,  4.12it/s]
# Epoch 5 in training:  99%|██████████████████████████████████████████████████████████ | 462/469 [02:12<00:01,  4.21it/s]
# Epoch 5 in training:  99%|██████████████████████████████████████████████████████████▏| 463/469 [02:12<00:01,  4.12it/s]
# Epoch 5 in training:  99%|██████████████████████████████████████████████████████████▎| 464/469 [02:13<00:01,  4.17it/s]
# Epoch 5 in training:  99%|██████████████████████████████████████████████████████████▍| 465/469 [02:13<00:00,  4.17it/s]
# Epoch 5 in training:  99%|██████████████████████████████████████████████████████████▌| 466/469 [02:13<00:00,  4.24it/s]
# Epoch 5 in training: 100%|██████████████████████████████████████████████████████████▋| 467/469 [02:13<00:00,  4.25it/s]
# Epoch 5 in training: 100%|██████████████████████████████████████████████████████████▊| 468/469 [02:13<00:00,  4.34it/s]
# Epoch 5 in training: 100%|███████████████████████████████████████████████████████████| 469/469 [02:14<00:00,  4.57it/s]
# Training: 100%|█████████████████████████████████████████████████████████████████████████| 5/5 [11:14<00:00, 134.83s/it]
# Epoch 5/5 loss: 0.41
# Making Predictions: 100%|██████████████████████████████████████████████████████████████| 79/79 [00:15<00:00,  5.04it/s]
# Actual labels for the first 10 samples:
# [7, 2, 1, 0, 4, 1, 4, 9, 5, 9]
# Predicted labels for the first 10 samples:
# [7, 2, 1, 0, 4, 1, 4, 4, 0, 9]
# Testing: 100%|█████████████████████████████████████████████████████████████████████████| 79/79 [00:15<00:00,  5.08it/s]
# Test loss: 0.36
# Test accuracy: 88.56%
# Predicted labels for the first 10 samples:
# [7, 2, 1, 0, 4, 1, 4, 4, 0, 9]
